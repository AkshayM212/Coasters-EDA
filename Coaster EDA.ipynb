# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
pd.set_option('display.max_column',100) #To display all columns in the dataset

# %%
df = pd.read_csv('coaster_db.csv')

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(2)
# Out:
#          coaster_name          Length             Speed       Location  \
# 0  Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)   Coney Island
# 1   Flip Flap Railway             NaN               NaN  Sea Lion Park
#
#     Status   Opening date  Type            Manufacturer Height restriction  \
# 0  Removed  June 16, 1884  Wood  LaMarcus Adna Thompson                NaN
# 1  Removed           1895  Wood            Lina Beecher                NaN
#
#          Model        Height  Inversions Lift/launch system Cost  \
# 0  Lift Packed  50 ft (15 m)         NaN            gravity  NaN
# 1          NaN           NaN         1.0                NaN  NaN
#
#                                               Trains  \
# 0                                                NaN
# 1  a single car. Riders are arranged 1 across in ...
#
#                 Park section Duration              Capacity G-force  \
# 0  Coney Island Cyclone Site     1:00  1600 riders per hour     2.9
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.isnull().sum()
# Out:
# coaster_name                        0
# Length                            134
# Speed                             150
# Location                            0
# Status                            213
# Opening date                      250
# Type                                0
# Manufacturer                       59
# Height restriction                256
# Model                             343
# Height                            122
# Inversions                        155
# Lift/launch system                292
# Cost                              705
# Trains                            369
# Park section                      600
# Duration                          322
# Capacity                          512
# G-force                           725
# Designer                          509
# Max vertical angle                730
# Drop                              593
# Soft opening date                 991
# Fast Lane available              1018
# Replaced                          914
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df = df[['coaster_name',
    #'Length', 'Speed',
    'Location', 'Status', 
    #'Opening date',
       #'Type',
    'Manufacturer', 
    #'Height restriction', 'Model', 'Height',
       #'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
       #'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
      # 'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
      # 'Track layout', 'Fastrack available', 'Soft opening date.1',
       #'Closing date', 
    #'Opened', 
    #'Replaced by', 'Website',
      # 'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
     #  'Single rider line available', 'Restraint Style',
     #  'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced',
    'latitude', 
    'longitude',
    'Type_Main',
       'opening_date_clean', 
    #'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #'height_value', 'height_unit', 
    'height_ft',
       'Inversions_clean', 'Gforce_clean']].copy()

# %%
df.shape
# Out:
# (1087, 13)

# %%
df.dtypes
# Out:
# coaster_name           object
# Location               object
# Status                 object
# Manufacturer           object
# year_introduced         int64
# latitude              float64
# longitude             float64
# Type_Main              object
# opening_date_clean     object
# speed_mph             float64
# height_ft             float64
# Inversions_clean        int64
# Gforce_clean          float64
# dtype: object

# %%
df['opening_date_clean'] = pd.to_datetime(df['opening_date_clean'])

# %%
#Rename columns
df = df.rename(columns = {'coaster_name':'Coaster_Name',
                     'year_introduced':'Year_Introduced',
                    'latitude':'Latitude',
                    'longitude':'Longitude',
                    'opening_date_clean':'Opening_Date',
                    'speed_mph':'Speed_Mph',
                    'height_ft':'Height_ft',
                    'Inversions_clean':'Inversions',
                    'Gforce_clean':'Gforce'})

# %%
df.head(3)
# Out:
#                              Coaster_Name                        Location  \
# 0                      Switchback Railway                    Coney Island
# 1                       Flip Flap Railway                   Sea Lion Park
# 2  Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
#
#     Status            Manufacturer  Year_Introduced  Latitude  Longitude  \
# 0  Removed  LaMarcus Adna Thompson             1884    40.574    -73.978
# 1  Removed            Lina Beecher             1895    40.578    -73.979
# 2   Closed                     NaN             1896    41.580    -81.570
#
#   Type_Main Opening_Date  Speed_Mph  Height_ft  Inversions  Gforce
# 0      Wood   1884-06-16        6.0        NaN           0     2.9
# 1      Wood   1895-01-01        NaN        NaN           1    12.0
# 2     Other          NaT        NaN        NaN           0     NaN

# %%
df.isnull().sum()
# Out:
# Coaster_Name         0
# Location             0
# Status             213
# Manufacturer        59
# Year_Introduced      0
# Latitude           275
# Longitude          275
# Type_Main            0
# Opening_Date       250
# Speed_Mph          150
# Height_ft          916
# Inversions           0
# Gforce             725
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1082    False
# 1083    False
# 1084    False
# 1085    False
# 1086    False
# Length: 1087, dtype: bool

# %%
df.loc[df.duplicated(subset=['Coaster_Name'])]
# Out:
#                             Coaster_Name                   Location  \
# 43                 Crystal Beach Cyclone         Crystal Beach Park
# 60                           Derby Racer               Revere Beach
# 61           Blue Streak (Conneaut Lake)         Conneaut Lake Park
# 167        Big Thunder Mountain Railroad                      Other
# 237    Thunder Run (Canada's Wonderland)        Canada's Wonderland
# ...                                  ...                        ...
# 1063                  Lil' Devil Coaster  Six Flags Great Adventure
# 1064  Little Dipper (Conneaut Lake Park)         Conneaut Lake Park
# 1080                          Iron Gwazi    Busch Gardens Tampa Bay
# 1082             American Dreier Looping                      Other
# 1084           Tron Lightcycle Power Run                      Other
#
#                   Status                                       Manufacturer  \
# ...

# %%
df.query("Coaster_Name == 'Crystal Beach Cyclone'")
# Out:
#              Coaster_Name            Location   Status        Manufacturer  \
# 39  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
# 43  Crystal Beach Cyclone  Crystal Beach Park  Removed  Traver Engineering
#
#     Year_Introduced  Latitude  Longitude Type_Main Opening_Date  Speed_Mph  \
# 39             1926   42.8617   -79.0598      Wood   1926-01-01       60.0
# 43             1927   42.8617   -79.0598      Wood   1926-01-01       60.0
#
#     Height_ft  Inversions  Gforce
# 39        NaN           0     4.0
# 43        NaN           0     4.0

# %%
 df.query("Coaster_Name == 'Derby Racer'")
# Out:
#    Coaster_Name      Location   Status    Manufacturer  Year_Introduced  \
# 14  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1911
# 60  Derby Racer  Revere Beach  Removed  Fred W. Pearce             1937
#
#     Latitude  Longitude Type_Main Opening_Date  Speed_Mph  Height_ft  \
# 14     42.42    -70.986      Wood   1911-01-01        NaN        NaN
# 60     42.42    -70.986      Wood   1911-01-01        NaN        NaN
#
#     Inversions  Gforce
# 14           0     NaN
# 60           0     NaN

# %%
df = df.loc[~df.duplicated(subset=['Coaster_Name','Location','Opening_Date'])].reset_index(drop=True).copy()

# %%
df.shape
# Out:
# (990, 13)

# %%
# Feature Engineering

# %%
ax = df['Year_Introduced'].value_counts().head(10).plot(kind='bar', title = 'Top 10 Years Coasters Introduced')

ax.set_xlabel('Years Introduced')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ax2 = df['Speed_Mph'].plot(kind='hist',bins=20, title = 'Coaster Speed Mph')
ax2.set_xlabel('Speed in Mph')
# Out:
# Text(0.5, 0, 'Speed in Mph')

# %%
ax3 = df['Speed_Mph'].plot(kind='kde', title = 'Coaster Speed Mph')
ax3.set_xlabel('Speed in Mph')
# Out:
# Text(0.5, 0, 'Speed in Mph')

# %%
df.plot(kind='scatter',x='Speed_Mph',y='Height_ft',title= 'Coaster Speed vs Height')
# Out:
# <Axes: title={'center': 'Coaster Speed vs Height'}, xlabel='Speed_Mph', ylabel='Height_ft'>

# %%
sns.scatterplot(x='Speed_Mph',y='Height_ft',hue='Year_Introduced',data=df)
# Out:
# <Axes: xlabel='Speed_Mph', ylabel='Height_ft'>

# %%
sns.pairplot(data=df,vars=['Year_Introduced','Speed_Mph','Height_ft','Inversions','Gforce'],hue='Type_Main')
# Out:
# D:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
corr_df = df[['Year_Introduced','Speed_Mph','Height_ft','Inversions','Gforce']].dropna().corr()

# %%
sns.heatmap(corr_df,annot=True)
# Out:
# <Axes: >

# %%
# Locations with fastest roller coasters with min 10 coasters

axe = df.query('Location != "Other"').groupby('Location')['Speed_Mph'].agg(['mean','count']).query('count>=10').sort_values('mean')['mean']\
.plot(kind='barh',title = 'Average Coaster Speed by Location')
axe.set_xlabel('Average Coaster Speed')
# Out:
# Text(0.5, 0, 'Average Coaster Speed')
